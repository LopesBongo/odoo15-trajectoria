# %% [markdown]
# <a href="https://colab.research.google.com/github/LopesBongo/odoo15-trajectoria/blob/main/programa_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# igual ou maior que 18 anos de idade é adulto

usuario = input('digite o seu usuario')
senha = input('digite a sua senha')


if usuario == 'Admin' and senha == '123admin' :

    print('Sucesso Login Permitido')

else :

    print('ERRO! Verifica Usuario ou Senha')
